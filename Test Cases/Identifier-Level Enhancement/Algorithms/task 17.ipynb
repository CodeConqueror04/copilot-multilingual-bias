# %%
"""
Test Case 17: Fibonacci Number
Category: Algorithms
Task: Calculate nth Fibonacci number
"""

def fibonacci(n):
    # Complete this function
    # Return nth Fibonacci number (0-indexed)
    # F(0)=0, F(1)=1, F(n)=F(n-1)+F(n-2)

# %%
"""
परीक्षण केस 17: फिबोनाची संख्या
श्रेणी: एल्गोरिदम
कार्य: nवीं फिबोनाची संख्या की गणना करें
"""

def fibonacci(क्रम):
    # इस फ़ंक्शन को पूरा करें
    # क्रम वीं फिबोनाची संख्या वापस करें (0-अनुक्रमित)
    # F(0)=0, F(1)=1, F(n)=F(n-1)+F(n-2)
