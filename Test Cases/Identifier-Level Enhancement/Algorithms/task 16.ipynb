# %%
"""
Test Case 16: Factorial Calculator
Category: Algorithms
Task: Calculate factorial of a number (iterative or recursive)
"""

def factorial(n):
    # Complete this function
    # Return factorial of n
    # Return 1 for n=0

# %%
"""
परीक्षण केस 16: फैक्टोरियल कैलकुलेटर
श्रेणी: एल्गोरिदम
कार्य: एक संख्या का फैक्टोरियल निकालें (पुनरावृत्तीय या पुनरावर्ती)
"""

def factorial(संख्या):
    # इस फ़ंक्शन को पूरा करें
    # संख्या का फैक्टोरियल वापस करें
    # संख्या=0 के लिए 1 वापस करें
