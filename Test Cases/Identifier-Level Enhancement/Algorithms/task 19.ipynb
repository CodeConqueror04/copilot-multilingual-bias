# %%
"""
Test Case 19: Reverse String
Category: Algorithms
Task: Reverse a string
"""

def reverse_string(text):
    # Complete this function
    # Return reversed string

# %%
"""
परीक्षण केस 19: स्ट्रिंग उलटें
श्रेणी: एल्गोरिदम
कार्य: एक स्ट्रिंग को उलटें
"""

def reverse_string(पाठ):
    # इस फ़ंक्शन को पूरा करें
    # उलटी स्ट्रिंग वापस करें
