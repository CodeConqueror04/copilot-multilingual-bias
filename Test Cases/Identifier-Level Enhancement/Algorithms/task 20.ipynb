# %%
"""
Test Case 20: Palindrome Checker
Category: Algorithms
Task: Check if a string is a palindrome (reads same forwards and backwards)
"""

def is_palindrome(text):
    # Complete this function
    # Return True if palindrome, False otherwise
    # Ignore case and spaces

# %%
"""
परीक्षण केस 20: पैलिंड्रोम जांचकर्ता
श्रेणी: एल्गोरिदम
कार्य: जांचें कि कोई स्ट्रिंग पैलिंड्रोम है या नहीं (आगे और पीछे से समान पढ़ा जाता है)
"""

def is_palindrome(पाठ):
    # इस फ़ंक्शन को पूरा करें
    # यदि पैलिंड्रोम है तो True, अन्यथा False वापस करें
    # केस और स्पेस को अनदेखा करें
