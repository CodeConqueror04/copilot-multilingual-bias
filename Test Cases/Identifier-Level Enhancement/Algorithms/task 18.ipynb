# %%
"""
Test Case 18: Prime Number Checker
Category: Algorithms
Task: Check if a number is prime
"""

def is_prime(number):
    # Complete this function
    # Return True if prime, False otherwise
    # Handle edge cases (n < 2)

# %%
"""
परीक्षण केस 18: अभाज्य संख्या जांचकर्ता
श्रेणी: एल्गोरिदम
कार्य: जांचें कि कोई संख्या अभाज्य है या नहीं
"""

def is_prime(संख्या):
    # इस फ़ंक्शन को पूरा करें
    # यदि अभाज्य है तो True, अन्यथा False वापस करें
    # किनारे के मामलों को संभालें (संख्या < 2)
