# %%
"""
Test Case 9: Leap Year Checker
Category: Conditional Logic
Task: Determine if a year is a leap year
"""

def is_leap_year(year):
    # Complete this function
    # Leap year rules: divisible by 4, except century years (divisible by 400)
    # Return True or False

# %%
"""
परीक्षण केस 9: लीप वर्ष जांचकर्ता
श्रेणी: सशर्त तर्क
कार्य: निर्धारित करें कि कोई वर्ष लीप वर्ष है या नहीं
"""

def is_leap_year(वर्ष):
    # इस फ़ंक्शन को पूरा करें
    # लीप वर्ष नियम: 4 से विभाज्य, सदी वर्षों को छोड़कर (400 से विभाज्य)
    # True या False वापस करें
