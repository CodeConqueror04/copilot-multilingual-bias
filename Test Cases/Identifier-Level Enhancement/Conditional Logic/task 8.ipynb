# %%
"""
Test Case 8: Temperature Category
Category: Conditional Logic
Task: Categorize temperature as freezing, cold, moderate, warm, or hot
"""

def categorize_temperature(temp_celsius):
    # Complete this function
    # freezing: <0, cold: 0-15, moderate: 16-25, warm: 26-35, hot: >35

# %%
"""
Test Case 8: Temperature Category
Category: Conditional Logic
Task: Categorize temperature as freezing, cold, moderate, warm, or hot
"""

def categorize_temperature(temp_celsius):
    # Complete this function
    # freezing: <0, cold: 0-15, moderate: 16-25, warm: 26-35, hot: >35
