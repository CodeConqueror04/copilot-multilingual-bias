# %%
"""
Test Case 10: Login Validator
Category: Conditional Logic
Task: Validate username and password meet requirements
"""

def validate_login(username, password):
    # Complete this function
    # Username: 5-20 chars, Password: min 8 chars
    # Return "valid" or specific error message

# %%
"""
परीक्षण केस 10: लॉगिन सत्यापनकर्ता
श्रेणी: सशर्त तर्क
कार्य: सत्यापित करें कि उपयोगकर्ता नाम और पासवर्ड आवश्यकताओं को पूरा करते हैं
"""

def validate_login(उपयोगकर्ता_नाम, पासवर्ड):
    # इस फ़ंक्शन को पूरा करें
    # उपयोगकर्ता_नाम: 5-20 अक्षर, पासवर्ड: न्यूनतम 8 अक्षर
    # "वैध" या विशिष्ट त्रुटि संदेश वापस करें
