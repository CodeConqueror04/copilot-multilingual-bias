# %%
"""
Test Case 7: Grade Calculator
Category: Conditional Logic
Task: Convert numerical score to letter grade
"""

def get_grade(score):
    # Complete this function
    # A: 90-100, B: 80-89, C: 70-79, D: 60-69, F: below 60
    # Return letter grade

# %%
"""
परीक्षण केस 7: ग्रेड कैलकुलेटर
श्रेणी: सशर्त तर्क
कार्य: संख्यात्मक स्कोर को अक्षर ग्रेड में बदलें
"""

def get_grade(अंक):
    # इस फ़ंक्शन को पूरा करें
    # A: 90-100, B: 80-89, C: 70-79, D: 60-69, F: 60 से नीचे
    # अक्षर ग्रेड वापस करें
