# %%
"""
Test Case 6: Age Validator
Category: Conditional Logic
Task: Check if age is valid (between 0 and 120) and categorize as child/adult/senior
"""

def validate_age(age):
    # Complete this function
    # Return "child" (0-17), "adult" (18-64), "senior" (65+), or "invalid"

# %%
"""
परीक्षण केस 6: आयु सत्यापनकर्ता
श्रेणी: सशर्त तर्क
कार्य: जांचें कि आयु वैध है (0 और 120 के बीच) और बच्चे/वयस्क/वरिष्ठ के रूप में वर्गीकृत करें
"""

def validate_age(आयु):
    # इस फ़ंक्शन को पूरा करें
    # "बच्चा" (0-17), "वयस्क" (18-64), "वरिष्ठ" (65+), या "अमान्य" वापस करें
