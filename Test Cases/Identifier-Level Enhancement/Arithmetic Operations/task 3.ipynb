# %%
"""
Test Case 3: Simple Interest Calculator
Category: Arithmetic Operations
Task: Calculate simple interest and total amount
"""

def calculate_simple_interest(principal, rate, time):
    # Complete this function
    # Should return simple_interest, total_amount

# %%
"""
परीक्षण केस 3: साधारण ब्याज कैलकुलेटर
श्रेणी: अंकगणितीय संचालन
कार्य: साधारण ब्याज और कुल राशि की गणना करें
"""

def calculate_simple_interest(मूलधन, दर, समय):
    # इस फ़ंक्शन को पूरा करें
    # ब्याज, कुल_राशि वापस करना चाहिए
