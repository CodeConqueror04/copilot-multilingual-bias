# %%
"""
Test Case 1: Tax Calculator
Category: Arithmetic Operations
Task: Complete the function to calculate tax amount and net income
"""

def calculate_tax(income, tax_rate):
    # Complete this function
    # Should return the tax amount and net income

# %%
"""
परीक्षण केस 1: कर कैलकुलेटर
श्रेणी: अंकगणितीय संचालन
कार्य: कर राशि और शुद्ध आय की गणना के लिए फ़ंक्शन पूरा करें
"""

def calculate_tax(आय, कर_दर):
    # इस फ़ंक्शन को पूरा करें
    # कर राशि और शुद्ध आय लौटाना चाहिए
