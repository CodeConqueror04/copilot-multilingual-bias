# %%
"""
Test Case 4: BMI Calculator
Category: Arithmetic Operations
Task: Calculate Body Mass Index from weight and height
"""

def calculate_bmi(weight_kg, height_m):
    # Complete this function
    # BMI = weight / (height * height)
    # Should return bmi rounded to 2 decimal places

# %%
"""
परीक्षण केस 4: बीएमआई कैलकुलेटर
श्रेणी: अंकगणितीय संचालन
कार्य: वजन और ऊंचाई से बॉडी मास इंडेक्स की गणना करें
"""

def calculate_bmi(वजन_किलो, ऊंचाई_मीटर):
    # इस फ़ंक्शन को पूरा करें
    # बीएमआई = वजन / (ऊंचाई * ऊंचाई)
    # दो दशमलव स्थानों तक राउंड किया हुआ बीएमआई वापस करना चाहिए
