# %%
"""
Test Case 2: Discount Calculator
Category: Arithmetic Operations
Task: Calculate final price after applying discount percentage
"""

def apply_discount(original_price, discount_percent):
    # Complete this function
    # Should return the final price after discount

# %%
"""
परीक्षण केस 2: छूट कैलकुलेटर
श्रेणी: अंकगणितीय संचालन
कार्य: छूट प्रतिशत लगाने के बाद अंतिम मूल्य की गणना करें
"""

def apply_discount(मूल_मूल्य, छूट_प्रतिशत):
    # इस फ़ंक्शन को पूरा करें
    # छूट के बाद अंतिम_मूल्य वापस करना चाहिए
