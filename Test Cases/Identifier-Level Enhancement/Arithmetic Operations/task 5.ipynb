# %%
"""
Test Case 5: Currency Converter
Category: Arithmetic Operations
Task: Convert amount from one currency to another using exchange rate
"""

def convert_currency(amount, exchange_rate):
    # Complete this function
    # Should return converted_amount rounded to 2 decimal places

# %%
"""
Test Case 5: Currency Converter
Category: Arithmetic Operations
Task: Convert amount from one currency to another using exchange rate
"""

def convert_currency(amount, exchange_rate):
    # Complete this function
    # Should return converted_amount rounded to 2 decimal places
