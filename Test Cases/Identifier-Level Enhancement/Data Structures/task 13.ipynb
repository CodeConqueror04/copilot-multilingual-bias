# %%
"""
Test Case 13: Count Occurrences
Category: Data Structures
Task: Count how many times a value appears in a list
"""

def count_occurrences(items, target):
    # Complete this function
    # Return count of target in items

# %%
"""
परीक्षण केस 13: घटनाओं की गणना करें
श्रेणी: डेटा संरचनाएं
कार्य: गिनें कि सूची में कोई मान कितनी बार प्रकट होता है
"""

def count_occurrences(वस्तुएं, लक्ष्य):
    # इस फ़ंक्शन को पूरा करें
    # वस्तुओं में लक्ष्य की गिनती वापस करें
