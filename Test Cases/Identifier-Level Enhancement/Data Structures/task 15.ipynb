# %%
"""
Test Case 15: Merge Dictionaries
Category: Data Structures
Task: Merge two dictionaries, with second dict values overwriting first
"""

def merge_dicts(dict1, dict2):
    # Complete this function
    # Return merged dictionary

# %%
"""
परीक्षण केस 15: शब्दकोश विलय करें
श्रेणी: डेटा संरचनाएं
कार्य: दो शब्दकोश मर्ज करें, दूसरे शब्दकोश के मान पहले को अधिलेखित करते हैं
"""

def merge_dicts(शब्दकोश1, शब्दकोश2):
    # इस फ़ंक्शन को पूरा करें
    # मर्ज किया गया शब्दकोश वापस करें
