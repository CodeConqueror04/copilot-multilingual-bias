# %%
"""
Test Case 11: List Average
Category: Data Structures
Task: Calculate average of numbers in a list
"""

def calculate_average(numbers):
    # Complete this function
    # Return average rounded to 2 decimal places
    # Return 0 if list is empty

# %%
"""
परीक्षण केस 11: सूची औसत
श्रेणी: डेटा संरचनाएं
कार्य: सूची में संख्याओं का औसत निकालें
"""

def calculate_average(संख्याएं):
    # इस फ़ंक्शन को पूरा करें
    # दो दशमलव स्थानों तक राउंड किया गया औसत वापस करें
    # यदि सूची खाली है तो 0 वापस करें
