# %% [markdown]
# # English Enhancement Prompts
#
# These prompts are used for prompt-level testing. Copy the minimal function and prompt into VS Code as a comment, then observe Copilot's enhancement.

# %%
# Task 1: Tax Calculator

def calculate_tax(income, tax_rate):
    return income * tax_rate

# Enhance this function with production-grade validation, comprehensive documentation, and error handling

# %%
# Task 2: Discount Calculator
def apply_discount(original_price, discount_percent):
    return original_price * (1 - discount_percent/100)

# Add professional-level input validation, type hints, docstring, and error handling to this function

# %%
# Task 3: Simple Interest Calculator

def calculate_simple_interest(principal, rate, time):
    return principal * rate * time / 100

# Enhance this with production-ready features including validation, documentation, and defensive programming

# %%
# Task 4: BMI Calculator
def calculate_bmi(weight_kg, height_m):
    return weight_kg / (height_m ** 2)

# Make this function production-grade with comprehensive validation, error handling, and documentation

# %%
# Task 5: Currency Converter
def convert_currency(amount, exchange_rate):
    return amount * exchange_rate

# Add professional standards: type hints, validation, error handling, and comprehensive docstring

# %%
# Task 6: Age Validator
def validate_age(age):
    if 0 <= age <= 17:
        return "child"
    elif 18 <= age <= 64:
        return "adult"
    else:
        return "senior"

# Enhance with production-level validation, error handling, edge cases, and documentation

# %%
# Task 7: Grade Calculator
def get_grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    else:
        return "F"

# Add comprehensive validation, error handling, docstring, and professional code standards

# %%
# Task 8: Temperature Category
def categorize_temperature(temp_celsius):
    if temp_celsius < 0:
        return "freezing"
    elif temp_celsius <= 15:
        return "cold"
    else:
        return "warm"

# Make this production-ready with validation, type hints, documentation, and error handling

# %%
# Task 9: Leap Year Checker
def is_leap_year(year):
    return (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)

# %%
# Task 10: Login Validator
def validate_login(username, password):
    if len(username) >= 5 and len(password) >= 8:
        return "valid"
    return "invalid"

# Add production-grade validation, specific error messages, documentation, and security considerations

# %%
# Task 11: List Average
def calculate_average(numbers):
    return sum(numbers) / len(numbers)

# Enhance with validation, error handling for empty lists, type hints, and comprehensive documentation

# %%
# Task 12: Find Maximum
def find_maximum(numbers):
    return max(numbers)

# Make production-ready with validation, empty list handling, documentation, and defensive programming

# %%
# Task 13: Count Occurrences
def count_occurrences(items, target):
    return items.count(target)

# Add professional standards: type hints, validation, edge case handling, and comprehensive docstring

# %%
# Task 14: Remove Duplicates
def remove_duplicates(items):
    seen = []
    for item in items:
        if item not in seen:
            seen.append(item)
    return seen

# Enhance with production-level code: validation, optimization, documentation, and error handling

# %%
# Task 15: Merge Dictionaries
def merge_dicts(dict1, dict2):
    result = dict1.copy()
    result.update(dict2)
    return result

# Add validation, type hints, comprehensive documentation, and error handling for production use

# %%
# Task 16: Factorial Calculator
def factorial(n):
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

# Make production-grade with validation, error handling, documentation, and edge case consideration

# %%
# Task 17: Fibonacci Number
def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n-1) + fibonacci(n-2)

# Enhance with optimization, validation, comprehensive docstring, and professional code standards

# %%
# Task 18: Prime Checker
def is_prime(number):
    if number < 2:
        return False
    for i in range(2, number):
        if number % i == 0:
            return False
    return True

# Add production features: optimization, validation, type hints, documentation, and error handling

# %%
# Task 19: Reverse String
def reverse_string(text):
    return text[::-1]

# Enhance with validation, type hints, comprehensive documentation, and professional standards

# %%
# Task 20: Palindrome Checker
def is_palindrome(text):
    cleaned = text.lower().replace(" ", "")
    return cleaned == cleaned[::-1]
# Make production-ready with validation, comprehensive docstring, type hints, and error handling
